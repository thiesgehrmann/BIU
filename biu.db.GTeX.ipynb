# %% [markdown]
# # Accessing GTeX
# Because GTeX is behind this ugly google login, you have to provide the files yourself.
# This can be done by specifying the exact location of the data.
# While the other datasets place the files deeper than the 'where' that you specify, GTeX will look EXACTLY for the following files:
#  * `'where'/GTEx_Analysis_2016-01-15_v7_RNASeQCv1.1.8_gene_tpm.gct.gz`
#  * `'where'/GTEx_Analysis_2016-01-15_v7_RSEMv1.2.22_transcript_tpm.txt.gz`
#  * `'where'/GTEx_v7_Annotations_SampleAttributesDS.txt`
#  * `'where'/GTEx_v7_Annotations_SubjectPhenotypesDS.txt`

# %%
import biu as biu
where = '/exports/molepi/tgehrmann/data/'
biu.config.settings.setWhere(where)

# %% [markdown]
# ## Loading the GTeX object

# %%
gtex = biu.db.GTeX(version="v7",
                   where="/exports/molepi/tgehrmann/data/gtex")
print(gtex)
# Out:
# GTeX object
#  Where: /exports/molepi/tgehrmann/data/gtex
#  Note: You must provide your own local copies using the 'localCopy' option!
#  Version: v7
#  Objects:
#   * [ ] sAttr
#   * [ ] sPheno
#  Files:
#   * [X] g_tpm : /exports/molepi/tgehrmann/data/gtex/GTEx_Analysis_2016-01-15_v7_RNASeQCv1.1.8_gene_tpm.gct.gz
#   * [X] t_tpm : /exports/molepi/tgehrmann/data/gtex/GTEx_Analysis_2016-01-15_v7_RSEMv1.2.22_transcript_tpm.txt.gz
#   * [X] s_attr : /exports/molepi/tgehrmann/data/gtex/GTEx_v7_Annotations_SampleAttributesDS.txt
#   * [X] s_pheno : /exports/molepi/tgehrmann/data/gtex/GTEx_v7_Annotations_SubjectPhenotypesDS.txt

# %% [markdown]
# ## Get the list of individuals in GTeX
# GTeX is constructed from individuals. You can see the list of people using `getPersonIDs`.

# %%
gtex.getPersonIDs()[:20]
# Out:
# D: Initializing the TSVResourceManager object NOW
# array(['1117F', '111CU', '111FC', '111VG', '111YS', '1122O', '1128S',
#        '113IC', '113JC', '117XS', '117YW', '117YX', '1192W', '1192X',
#        '11DXW', '11DXX', '11DXY', '11DXZ', '11DYG', '11DZ1'], dtype=object)

# %% [markdown]
# ### Get sample IDs for a specific person

# %%
pID = gtex.getPersonIDs()[0]
gtex.getPersonIDSamples(pID)
# Out:
# array(['GTEX-1117F-0226-SM-5GZZ7', 'GTEX-1117F-0426-SM-5EGHI',
#        'GTEX-1117F-0526-SM-5EGHJ', 'GTEX-1117F-0626-SM-5N9CS',
#        'GTEX-1117F-0726-SM-5GIEN', 'GTEX-1117F-1326-SM-5EGHH',
#        'GTEX-1117F-2226-SM-5N9CH', 'GTEX-1117F-2426-SM-5EGGH',
#        'GTEX-1117F-2526-SM-5GZY6', 'GTEX-1117F-2826-SM-5GZXL',
#        'GTEX-1117F-2926-SM-5GZYI', 'GTEX-1117F-3026-SM-5GZYU',
#        'GTEX-1117F-3226-SM-5N9CT'], dtype=object)

# %% [markdown]
# ### Get sample IDs for a specific tissue type for a specific person

# %%
gtex.getPersonIDTissueSampleID(pID, 'Adipose - Subcutaneous')
# Out:
# array(['GTEX-1117F-0226-SM-5GZZ7'], dtype=object)

# %%
### Get all

# %% [markdown]
# ### Get attributes for all samples of a specific person

# %%
gtex.getPersonIDAttrRows(pID)
# Out:
#                       SAMPID  SMATSSCR SMCENTER  \
# 0   GTEX-1117F-0003-SM-58Q7G       NaN       B1
# 1   GTEX-1117F-0003-SM-5DWSB       NaN       B1
# 2   GTEX-1117F-0003-SM-6WBT7       NaN       B1
# 3   GTEX-1117F-0226-SM-5GZZ7       0.0       B1
# 4   GTEX-1117F-0426-SM-5EGHI       0.0       B1
# 5   GTEX-1117F-0526-SM-5EGHJ       0.0       B1
# 6   GTEX-1117F-0626-SM-5N9CS       1.0       B1
# 7   GTEX-1117F-0726-SM-5GIEN       1.0       B1
# 8   GTEX-1117F-1326-SM-5EGHH       1.0       B1
# 9   GTEX-1117F-2226-SM-5N9CH       1.0       B1
# 10  GTEX-1117F-2426-SM-5EGGH       1.0       B1
# 11  GTEX-1117F-2526-SM-5GZY6       2.0       B1
# 12  GTEX-1117F-2826-SM-5GZXL       1.0       B1
# 13  GTEX-1117F-2926-SM-5GZYI       0.0       B1
# 14  GTEX-1117F-3026-SM-5GZYU       1.0       B1
# 15  GTEX-1117F-3226-SM-5N9CT       1.0       B1
#
#                                              SMPTHNTS  SMRIN            SMTS  \
# 0                                                 NaN    NaN           Blood
# 1                                                 NaN    NaN           Blood
# 2                                                 NaN    NaN           Blood
# 3        2 pieces, ~15% vessel stroma, rep delineated    6.8  Adipose Tissue
# 4   2 pieces, !5% fibrous connective tissue, delin...    7.1          Muscle
# 5   2 pieces, clean, Monckebeg medial sclerosis, r...    8.0    Blood Vessel
# 6   2 pieces, up to 4mm aderent fat/nerve/vessel, ...    6.9    Blood Vessel
# 7                          2 pieces, no abnormalities    6.3           Heart
# 8   2 pieces, diffuse mesothelial hyperplasia; ~10...    5.9  Adipose Tissue
# 9   1 piece vascular tissue, probably ovarian hilu...    6.6           Ovary
# 10  1 piece mymetrial smooth muscle as in correson...    6.3          Uterus
# 11  6  pieces, squamous epithelium is ~ 2-3% thick...    6.5          Vagina
# 12  2 pieces, fibrocystic changes, rep ductal/lobu...    5.8          Breast
# 13  6 pieces, minimal fat, squamous epithelium is ...    7.7            Skin
# 14  2 pieces, generally good, one aliquot has ~25%...    8.3  Salivary Gland
# 15                                           2 pieces    6.2           Brain
#
#                                   SMTSD  SMUBRID  SMTSISCH  SMTSPAX  \
# 0                           Whole Blood  0013756    1188.0      NaN
# 1                           Whole Blood  0013756    1188.0      NaN
# 2                           Whole Blood  0013756    1188.0      NaN
# 3                Adipose - Subcutaneous  0002190    1214.0   1125.0
# 4                     Muscle - Skeletal  0011907    1220.0   1119.0
# 5                       Artery - Tibial  0007610    1221.0   1120.0
# 6                     Artery - Coronary  0001621    1243.0   1098.0
# 7              Heart - Atrial Appendage  0006631    1244.0   1097.0
# 8          Adipose - Visceral (Omentum)  0010414    1277.0   1066.0
# 9                                 Ovary  0000992    1326.0   1020.0
# 10                               Uterus  0000995    1332.0   1014.0
# 11                               Vagina  0000996    1329.0   1017.0
# 12              Breast - Mammary Tissue  0008367    1340.0   1008.0
# 13  Skin - Not Sun Exposed (Suprapubic)  0036149    1341.0   1006.0
# 14                 Minor Salivary Gland  0006330    1343.0   1005.0
# 15                       Brain - Cortex  0001870    1418.0    931.0
#
#       ...        SME1ANTI    SMSPLTRD  SMBSMMRT    SME1SNSE   SME1PCTS  \
# 0     ...             NaN         NaN       NaN         NaN        NaN
# 1     ...             NaN         NaN       NaN         NaN        NaN
# 2     ...             NaN         NaN       NaN         NaN        NaN
# 3     ...      14579275.0  12025354.0  0.003164  14634407.0  50.094357
# 4     ...      13134349.0  11578874.0  0.003991  13307871.0  50.328114
# 5     ...      13169835.0  11015113.0  0.004285  13160068.0  49.981450
# 6     ...      15148343.0  11624467.0  0.003379  15282444.0  50.220333
# 7     ...      13583226.0   9262806.0  0.003451  13745609.0  50.297090
# 8     ...      13342709.0   9625148.0  0.004869  13393827.0  50.095592
# 9     ...      15767801.0  12721979.0  0.003328  15920208.0  50.240480
# 10    ...      12717931.0   9271556.0  0.004069  12699861.0  49.964450
# 11    ...      19151917.0  13134648.0  0.004509  19211792.0  50.078037
# 12    ...      14958322.0  11475930.0  0.003272  15123116.0  50.273910
# 13    ...      14578550.0  11646185.0  0.003300  14627683.0  50.084114
# 14    ...      14166989.0  10597805.0  0.003429  14197513.0  50.053806
# 15    ...      17436047.0   8168722.0  0.003512  17758650.0  50.458313
#
#     SMRRNART  SME1MPRT SMNUM5CD  SMDPMPRT   SME2PCTS
# 0        NaN       NaN      NaN       NaN        NaN
# 1        NaN       NaN      NaN       NaN        NaN
# 2        NaN       NaN      NaN       NaN        NaN
# 3   0.003102  0.992826      NaN       0.0  50.126280
# 4   0.006991  0.994212      NaN       0.0  49.905170
# 5   0.002867  0.992711      NaN       0.0  50.227848
# 6   0.005335  0.991175      NaN       0.0  50.025043
# 7   0.030579  0.994478      NaN       0.0  49.929870
# 8   0.010321  0.989115      NaN       0.0  50.058605
# 9   0.002097  0.990144      NaN       0.0  49.962017
# 10  0.003749  0.991903      NaN       0.0  50.274200
# 11  0.003700  0.991048      NaN       0.0  50.034920
# 12  0.015008  0.992529      NaN       0.0  49.973570
# 13  0.004957  0.992913      NaN       0.0  50.099700
# 14  0.004185  0.991469      NaN       0.0  49.999527
# 15  0.062019  0.993172      NaN       0.0  50.106678
#
# [16 rows x 63 columns]

# %%
print(gtex.getPersonIDSamples(gtex.getPersonIDs()[0]))
