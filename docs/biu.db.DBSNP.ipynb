# %% [markdown]
# # Accessing the dbSNP database
# The dbSNP database is accessed through a VCF file.
# It is quite a large VCF file (7GB) which takes some time to download

# %%
import biu

where = '/exports/molepi/tgehrmann/data/'
biu.config.settings.setWhere(where)

dbsnp = biu.db.DBSNP("human_9606_b150_GRCh37p13")

# %%
print(dbsnp)
# Out:
# DBSNP object
#  Where: /exports/molepi/tgehrmann/data
#  Version : human_9606_b150_GRCh37p13
#  Objects:
#   * [ ] vcf
#   * [ ] info
#  Files:
#   * [X] vcf : /exports/molepi/tgehrmann/data/dbSNP_human_9606_b150_GRCh37p13/all_snps.vcf.bgz
#   * [X] tbi : /exports/molepi/tgehrmann/data/dbSNP_human_9606_b150_GRCh37p13/all_snps.vcf.bgz.tbi
#   * [ ] info : /exports/molepi/tgehrmann/data/dbSNP_human_9606_b150_GRCh37p13/info_dict.sqldict.sqlite

# %% [markdown]
# ## Querying the dbSNP database

# %%
for record in dbsnp.query("1", 10019, 10165):
    print(record.INFO['RS'], record)
# Out:
# 775809821 Record(CHROM=1, POS=10019, REF=TA, ALT=[T])
# 978760828 Record(CHROM=1, POS=10039, REF=A, ALT=[C])
# 1008829651 Record(CHROM=1, POS=10043, REF=T, ALT=[A])
# 1052373574 Record(CHROM=1, POS=10051, REF=A, ALT=[G])
# 892501864 Record(CHROM=1, POS=10055, REF=T, ALT=[A])
# 768019142 Record(CHROM=1, POS=10055, REF=T, ALT=[TA])
# 1010989343 Record(CHROM=1, POS=10063, REF=A, ALT=[C])
# 1022805358 Record(CHROM=1, POS=10077, REF=C, ALT=[G])
# 62651026 Record(CHROM=1, POS=10108, REF=C, ALT=[T])
# 376007522 Record(CHROM=1, POS=10109, REF=A, ALT=[T])
# 796688738 Record(CHROM=1, POS=10128, REF=A, ALT=[AC])
# 368469931 Record(CHROM=1, POS=10139, REF=A, ALT=[T])
# 144773400 Record(CHROM=1, POS=10144, REF=TA, ALT=[T])
# 779258992 Record(CHROM=1, POS=10146, REF=AC, ALT=[A])
# 371194064 Record(CHROM=1, POS=10150, REF=C, ALT=[T])
# 796884232 Record(CHROM=1, POS=10165, REF=A, ALT=[AC])
# D: Initializing the VCFResourceManager object NOW
# D: VCF Input source is tabixed file.
# D: VCF Input source is list of Records.

# %% [markdown]
# ## Look up a specific variant

# %%
dbsnp("22", 39917515, "C")
# Out:
# D: VCF Input source is list of Records.
# 'rs4894'

# %% [markdown]
# ## Look up a dbSNP ID

# %%
dbsnp["rs4894"]
# Out:
# {'citations': [18163433],
#  'create_date': '2000-09-19T17:02Z',
#  'dbsnp1_merges': [{'merge_date': '2002-07-3T13:34Z',
#    'merged_rsid': '3175832',
#    'revision': '106'},
#   {'merge_date': '2003-02-20T13:23Z',
#    'merged_rsid': '3859851',
#    'revision': '111'},
#   {'merge_date': '2004-12-2T11:52Z',
#    'merged_rsid': '11556098',
#    'revision': '124'},
#   {'merge_date': '2006-03-11T06:54Z',
#    'merged_rsid': '17850300',
#    'revision': '126'},
#   {'merge_date': '2006-03-11T06:54Z',
#    'merged_rsid': '17850840',
#    'revision': '126'},
#   {'merge_date': '2006-03-11T06:54Z',
#    'merged_rsid': '17852243',
#    'revision': '126'}],
#  'last_update_build_id': '150',
#  'last_update_date': '2018-03-4T14:03Z',
#  'lost_obs_movements': [],
#  'present_obs_movements': [{'allele_in_cur_release': {'deleted_sequence': 'A',
#     'inserted_sequence': 'A',
#     'position': 39521509,
#     'seq_id': 'NC_000022.11'},
#    'component_ids': [{'type': 'subsnp', 'value': '167982926'},
#     {'type': 'subsnp', 'value': '171998650'},
#     {'type': 'subsnp', 'value': '204095544'},
#     {'type': 'subsnp', 'value': '283644119'},
#     {'type': 'subsnp', 'value': '287573031'},
#     {'type': 'subsnp', 'value': '491825004'},
#     {'type': 'subsnp', 'value': '1699448412'},
#     {'type': 'subsnp', 'value': '2136840570'}],
#    'last_added_to_this_rs': '150',
#    'observation': {'deleted_sequence': 'A',
#     'inserted_sequence': 'A',
#     'position': 38247460,
#     'seq_id': 'NC_000022.9'},
#    'rsids_in_cur_release': []},
#   {'allele_in_cur_release': {'deleted_sequence': 'A',
#     'inserted_sequence': 'A',
#     'position': 39521509,
#     'seq_id': 'NC_000022.11'},
#    'component_ids': [{'type': 'frequency', 'value': '1000Genomes.1:80822908'},
#     {'type': 'frequency', 'value': 'ALSPAC.1:44706681'},
#     {'type': 'frequency', 'value': 'ESP6500SI-V2.1:1907169'},
#     {'type': 'frequency', 'value': 'ExAC.1:5940423'},
#     {'type': 'frequency', 'value': 'GnomAD.1:128030033'},
#     {'type': 'frequency', 'value': 'TOPMED.1:93016551'},
#     {'type': 'frequency', 'value': 'TWINSUK.1:44706681'},
#     {'type': 'subsnp', 'value': '341187171'},
#     {'type': 'subsnp', 'value': '342543467'},
#     {'type': 'subsnp', 'value': '482104014'},
#     {'type': 'subsnp', 'value': '491193453'},
#     {'type': 'subsnp', 'value': '491572090'},
#     {'type': 'subsnp', 'value': '566657448'},
#     {'type': 'subsnp', 'value': '662586525'},
#     {'type': 'subsnp', 'value': '995377109'},
#     {'type': 'subsnp', 'value': '1067606697'},
#     {'type': 'subsnp', 'value': '1082676753'},
#     {'type': 'subsnp', 'value': '1367267142'},
#     {'type': 'subsnp', 'value': '1429264090'},
#     {'type': 'subsnp', 'value': '1584128112'},
#     {'type': 'subsnp', 'value': '1640046802'},
#     {'type': 'subsnp', 'value': '1683040835'},
#     {'type': 'subsnp', 'value': '1694358673'},
#     {'type': 'subsnp', 'value': '1711570323'},
#     {'type': 'subsnp', 'value': '1938945194'},
#     {'type': 'subsnp', 'value': '1959982477'},
#     {'type': 'subsnp', 'value': '1969277163'},
#     {'type': 'subsnp', 'value': '2030245075'},
#     {'type': 'subsnp', 'value': '2158864568'},
#     {'type': 'subsnp', 'value': '2414513736'},
#     {'type': 'subsnp', 'value': '2745159603'},
#     {'type': 'subsnp', 'value': '2750562012'},
#     {'type': 'subsnp', 'value': '2974676167'},
#     {'type': 'subsnp', 'value': '2985856796'},
#     {'type': 'subsnp', 'value': '3019346144'},
#     {'type': 'subsnp', 'value': '3022189307'},
#     {'type': 'subsnp', 'value': '3023073564'}],
#    'last_added_to_this_rs': '150',
#    'observation': {'deleted_sequence': 'A',
#     'inserted_sequence': 'A',
#     'position': 39917514,
#     'seq_id': 'NC_000022.10'},
#    'rsids_in_cur_release': []},
#   {'allele_in_cur_release': {'deleted_sequence': 'A',
#     'inserted_sequence': 'A',
#     'position': 39521509,
#     'seq_id': 'NC_000022.11'},
#    'component_ids': [{'type': 'subsnp', 'value': '76897193'}],
#    'last_added_to_this_rs': '150',
#    'observation': {'deleted_sequence': 'A',
#     'inserted_sequence': 'A',
#     'position': 19308029,
#     'seq_id': 'NT_011520.11'},
#    'rsids_in_cur_release': []},
#   {'allele_in_cur_release': {'deleted_sequence': 'A',
#     'inserted_sequence': 'A',
#     'position': 39521509,
#     'seq_id': 'NC_000022.11'},
#    'component_ids': [{'type': 'subsnp', 'value': '5336'},
#     {'type': 'subsnp', 'value': '85589'},
#     {'type': 'subsnp', 'value': '1542101'},
#     {'type': 'subsnp', 'value': '1543395'},
#     {'type': 'subsnp', 'value': '3172836'},
#     {'type': 'subsnp', 'value': '4399381'},
#     {'type': 'subsnp', 'value': '4428742'},
#     {'type': 'subsnp', 'value': '5298654'},
#     {'type': 'subsnp', 'value': '6052612'},
#     {'type': 'subsnp', 'value': '7998332'},
#     {'type': 'subsnp', 'value': '16261117'},
#     {'type': 'subsnp', 'value': '28504602'},
#     {'type': 'subsnp', 'value': '28505142'},
#     {'type': 'subsnp', 'value': '28506545'},
#     {'type': 'subsnp', 'value': '41518359'},
#     {'type': 'subsnp', 'value': '46563727'},
#     {'type': 'subsnp', 'value': '48402331'},
#     {'type': 'subsnp', 'value': '76868677'},
#     {'type': 'subsnp', 'value': '96126931'},
#     {'type': 'subsnp', 'value': '143466153'},
#     {'type': 'subsnp', 'value': '159744578'},
#     {'type': 'subsnp', 'value': '160724750'}],
#    'last_added_to_this_rs': '150',
#    'observation': {'deleted_sequence': 'A',
#     'inserted_sequence': 'A',
#     'position': 19308083,
#     'seq_id': 'NT_011520.12'},
#    'rsids_in_cur_release': []},
#   {'allele_in_cur_release': {'deleted_sequence': 'A',
#     'inserted_sequence': 'C',
#     'position': 39521509,
#     'seq_id': 'NC_000022.11'},
#    'component_ids': [{'type': 'subsnp', 'value': '167982926'},
#     {'type': 'subsnp', 'value': '171998650'},
#     {'type': 'subsnp', 'value': '204095544'},
#     {'type': 'subsnp', 'value': '283644119'},
#     {'type': 'subsnp', 'value': '287573031'},
#     {'type': 'subsnp', 'value': '491825004'},
#     {'type': 'subsnp', 'value': '1699448412'},
#     {'type': 'subsnp', 'value': '2136840570'}],
#    'last_added_to_this_rs': '150',
#    'observation': {'deleted_sequence': 'A',
#     'inserted_sequence': 'C',
#     'position': 38247460,
#     'seq_id': 'NC_000022.9'},
#    'rsids_in_cur_release': []},
#   {'allele_in_cur_release': {'deleted_sequence': 'A',
#     'inserted_sequence': 'C',
#     'position': 39521509,
#     'seq_id': 'NC_000022.11'},
#    'component_ids': [{'type': 'frequency', 'value': '1000Genomes.1:80822908'},
#     {'type': 'frequency', 'value': 'ALSPAC.1:44706681'},
#     {'type': 'frequency', 'value': 'ESP6500SI-V2.1:1907169'},
#     {'type': 'frequency', 'value': 'ExAC.1:5940423'},
#     {'type': 'frequency', 'value': 'GnomAD.1:128030033'},
#     {'type': 'frequency', 'value': 'TOPMED.1:93016551'},
#     {'type': 'frequency', 'value': 'TWINSUK.1:44706681'},
#     {'type': 'subsnp', 'value': '341187171'},
#     {'type': 'subsnp', 'value': '342543467'},
#     {'type': 'subsnp', 'value': '482104014'},
#     {'type': 'subsnp', 'value': '491193453'},
#     {'type': 'subsnp', 'value': '491572090'},
#     {'type': 'subsnp', 'value': '566657448'},
#     {'type': 'subsnp', 'value': '662586525'},
#     {'type': 'subsnp', 'value': '995377109'},
#     {'type': 'subsnp', 'value': '1067606697'},
#     {'type': 'subsnp', 'value': '1082676753'},
#     {'type': 'subsnp', 'value': '1367267142'},
#     {'type': 'subsnp', 'value': '1429264090'},
#     {'type': 'subsnp', 'value': '1584128112'},
#     {'type': 'subsnp', 'value': '1640046802'},
#     {'type': 'subsnp', 'value': '1683040835'},
#     {'type': 'subsnp', 'value': '1694358673'},
#     {'type': 'subsnp', 'value': '1711570323'},
#     {'type': 'subsnp', 'value': '1938945194'},
#     {'type': 'subsnp', 'value': '1959982477'},
#     {'type': 'subsnp', 'value': '1969277163'},
#     {'type': 'subsnp', 'value': '2030245075'},
#     {'type': 'subsnp', 'value': '2158864568'},
#     {'type': 'subsnp', 'value': '2414513736'},
#     {'type': 'subsnp', 'value': '2745159603'},
#     {'type': 'subsnp', 'value': '2750562012'},
#     {'type': 'subsnp', 'value': '2974676167'},
#     {'type': 'subsnp', 'value': '2985856796'},
#     {'type': 'subsnp', 'value': '3019346144'},
#     {'type': 'subsnp', 'value': '3022189307'},
#     {'type': 'subsnp', 'value': '3023073564'}],
#    'last_added_to_this_rs': '150',
#    'observation': {'deleted_sequence': 'A',
#     'inserted_sequence': 'C',
#     'position': 39917514,
#     'seq_id': 'NC_000022.10'},
#    'rsids_in_cur_release': []},
#   {'allele_in_cur_release': {'deleted_sequence': 'A',
#     'inserted_sequence': 'C',
#     'position': 39521509,
#     'seq_id': 'NC_000022.11'},
#    'component_ids': [{'type': 'subsnp', 'value': '76897193'}],
#    'last_added_to_this_rs': '150',
#    'observation': {'deleted_sequence': 'A',
#     'inserted_sequence': 'C',
#     'position': 19308029,
#     'seq_id': 'NT_011520.11'},
#    'rsids_in_cur_release': []},
#   {'allele_in_cur_release': {'deleted_sequence': 'A',
#     'inserted_sequence': 'C',
#     'position': 39521509,
#     'seq_id': 'NC_000022.11'},
#    'component_ids': [{'type': 'subsnp', 'value': '5336'},
#     {'type': 'subsnp', 'value': '85589'},
#     {'type': 'subsnp', 'value': '1542101'},
#     {'type': 'subsnp', 'value': '1543395'},
#     {'type': 'subsnp', 'value': '3172836'},
#     {'type': 'subsnp', 'value': '4399381'},
#     {'type': 'subsnp', 'value': '4428742'},
#     {'type': 'subsnp', 'value': '5298654'},
#     {'type': 'subsnp', 'value': '6052612'},
#     {'type': 'subsnp', 'value': '7998332'},
#     {'type': 'subsnp', 'value': '16261117'},
#     {'type': 'subsnp', 'value': '28504602'},
#     {'type': 'subsnp', 'value': '28505142'},
#     {'type': 'subsnp', 'value': '28506545'},
#     {'type': 'subsnp', 'value': '41518359'},
#     {'type': 'subsnp', 'value': '46563727'},
#     {'type': 'subsnp', 'value': '48402331'},
#     {'type': 'subsnp', 'value': '76868677'},
#     {'type': 'subsnp', 'value': '96126931'},
#     {'type': 'subsnp', 'value': '143466153'},
#     {'type': 'subsnp', 'value': '159744578'},
#     {'type': 'subsnp', 'value': '160724750'}],
#    'last_added_to_this_rs': '150',
#    'observation': {'deleted_sequence': 'A',
#     'inserted_sequence': 'C',
#     'position': 19308083,
#     'seq_id': 'NT_011520.12'},
#    'rsids_in_cur_release': []}],
#  'primary_snapshot_data': {'allele_annotations': [{'assembly_annotation': [{'annotation_release': 'Homo sapiens Annotation Release 108',
#       'genes': [{'id': 468,
#         'is_pseudo': False,
#         'locus': 'ATF4',
#         'name': 'activating transcription factor 4',
#         'orientation': 'plus',
#         'rnas': [{'id': 'NM_001675.4',
#           'product_id': 'NP_001666.2',
#           'protein': {'sequence_ontology': [],
#            'variant': {'spdi': {'deleted_sequence': 'Q',
#              'inserted_sequence': 'Q',
#              'position': 21,
#              'seq_id': 'NP_001666.2'}}},
#           'sequence_ontology': [{'accession': 'SO:0001580',
#             'name': 'coding_sequence_variant'}],
#           'transcript_change': {'deleted_sequence': 'CAG',
#            'inserted_sequence': 'CAG',
#            'position': 950,
#            'seq_id': 'NM_001675.4'}},
#          {'id': 'NM_182810.2',
#           'product_id': 'NP_877962.1',
#           'protein': {'sequence_ontology': [],
#            'variant': {'spdi': {'deleted_sequence': 'Q',
#              'inserted_sequence': 'Q',
#              'position': 21,
#              'seq_id': 'NP_877962.1'}}},
#           'sequence_ontology': [{'accession': 'SO:0001580',
#             'name': 'coding_sequence_variant'}],
#           'transcript_change': {'deleted_sequence': 'CAG',
#            'inserted_sequence': 'CAG',
#            'position': 343,
#            'seq_id': 'NM_182810.2'}},
#          {'id': 'XM_017028807.1',
#           'product_id': 'XP_016884296.1',
#           'protein': {'sequence_ontology': [],
#            'variant': {'spdi': {'deleted_sequence': 'Q',
#              'inserted_sequence': 'Q',
#              'position': 21,
#              'seq_id': 'XP_016884296.1'}}},
#           'sequence_ontology': [{'accession': 'SO:0001580',
#             'name': 'coding_sequence_variant'}],
#           'transcript_change': {'deleted_sequence': 'CAG',
#            'inserted_sequence': 'CAG',
#            'position': 822,
#            'seq_id': 'XM_017028807.1'}}],
#         'sequence_ontology': []}],
#       'seq_id': 'NC_000022.11'}],
#     'clinical': [],
#     'frequency': [{'allele_count': 3637,
#       'common': False,
#       'local_row_id': 80822908,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'A',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': '1000Genomes',
#       'study_version': 1,
#       'total_count': 5008},
#      {'allele_count': 2602,
#       'common': False,
#       'local_row_id': 44706681,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'A',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': 'ALSPAC',
#       'study_version': 1,
#       'total_count': 3854},
#      {'allele_count': 3931,
#       'common': False,
#       'local_row_id': 1907169,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'A',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': 'ESP6500SI-V2',
#       'study_version': 1,
#       'total_count': 13006},
#      {'allele_count': 83023,
#       'common': False,
#       'local_row_id': 5940423,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'A',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': 'ExAC',
#       'study_version': 1,
#       'total_count': 119740},
#      {'allele_count': 20718,
#       'common': False,
#       'local_row_id': 128030033,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'A',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': 'GnomAD',
#       'study_version': 1,
#       'total_count': 29916},
#      {'allele_count': 20474,
#       'common': False,
#       'local_row_id': 93016551,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'A',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': 'TOPMED',
#       'study_version': 1,
#       'total_count': 29114},
#      {'allele_count': 2603,
#       'common': False,
#       'local_row_id': 44706681,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'A',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': 'TWINSUK',
#       'study_version': 1,
#       'total_count': 3708}],
#     'submissions': ['5336',
#      '85589',
#      '1542101',
#      '1543395',
#      '3172836',
#      '4399381',
#      '4428742',
#      '5298654',
#      '6052612',
#      '7998332',
#      '16261117',
#      '28504602',
#      '28505142',
#      '28506545',
#      '41518359',
#      '46563727',
#      '48402331',
#      '76868677',
#      '76897193',
#      '96126931',
#      '143466153',
#      '159744578',
#      '160724750',
#      '167982926',
#      '171998650',
#      '204095544',
#      '283644119',
#      '287573031',
#      '341187171',
#      '342543467',
#      '482104014',
#      '491193453',
#      '491572090',
#      '491825004',
#      '566657448',
#      '662586525',
#      '995377109',
#      '1067606697',
#      '1082676753',
#      '1367267142',
#      '1429264090',
#      '1584128112',
#      '1640046802',
#      '1683040835',
#      '1694358673',
#      '1699448412',
#      '1711570323',
#      '1938945194',
#      '1959982477',
#      '1969277163',
#      '2030245075',
#      '2136840570',
#      '2158864568',
#      '2414513736',
#      '2745159603',
#      '2750562012',
#      '2974676167',
#      '2985856796',
#      '3019346144',
#      '3022189307',
#      '3023073564']},
#    {'assembly_annotation': [{'annotation_release': 'Homo sapiens Annotation Release 108',
#       'genes': [{'id': 468,
#         'is_pseudo': False,
#         'locus': 'ATF4',
#         'name': 'activating transcription factor 4',
#         'orientation': 'plus',
#         'rnas': [{'id': 'NM_001675.4',
#           'product_id': 'NP_001666.2',
#           'protein': {'sequence_ontology': [{'accession': 'SO:0001583',
#              'name': 'missense_variant'}],
#            'variant': {'spdi': {'deleted_sequence': 'Q',
#              'inserted_sequence': 'P',
#              'position': 21,
#              'seq_id': 'NP_001666.2'}}},
#           'sequence_ontology': [{'accession': 'SO:0001580',
#             'name': 'coding_sequence_variant'}],
#           'transcript_change': {'deleted_sequence': 'CAG',
#            'inserted_sequence': 'CCG',
#            'position': 950,
#            'seq_id': 'NM_001675.4'}},
#          {'id': 'NM_182810.2',
#           'product_id': 'NP_877962.1',
#           'protein': {'sequence_ontology': [{'accession': 'SO:0001583',
#              'name': 'missense_variant'}],
#            'variant': {'spdi': {'deleted_sequence': 'Q',
#              'inserted_sequence': 'P',
#              'position': 21,
#              'seq_id': 'NP_877962.1'}}},
#           'sequence_ontology': [{'accession': 'SO:0001580',
#             'name': 'coding_sequence_variant'}],
#           'transcript_change': {'deleted_sequence': 'CAG',
#            'inserted_sequence': 'CCG',
#            'position': 343,
#            'seq_id': 'NM_182810.2'}},
#          {'id': 'XM_017028807.1',
#           'product_id': 'XP_016884296.1',
#           'protein': {'sequence_ontology': [{'accession': 'SO:0001583',
#              'name': 'missense_variant'}],
#            'variant': {'spdi': {'deleted_sequence': 'Q',
#              'inserted_sequence': 'P',
#              'position': 21,
#              'seq_id': 'XP_016884296.1'}}},
#           'sequence_ontology': [{'accession': 'SO:0001580',
#             'name': 'coding_sequence_variant'}],
#           'transcript_change': {'deleted_sequence': 'CAG',
#            'inserted_sequence': 'CCG',
#            'position': 822,
#            'seq_id': 'XM_017028807.1'}}],
#         'sequence_ontology': []}],
#       'seq_id': 'NC_000022.11'}],
#     'clinical': [],
#     'frequency': [{'allele_count': 1371,
#       'common': False,
#       'local_row_id': 80822908,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'C',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': '1000Genomes',
#       'study_version': 1,
#       'total_count': 5008},
#      {'allele_count': 1252,
#       'common': False,
#       'local_row_id': 44706681,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'C',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': 'ALSPAC',
#       'study_version': 1,
#       'total_count': 3854},
#      {'allele_count': 9075,
#       'common': False,
#       'local_row_id': 1907169,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'C',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': 'ESP6500SI-V2',
#       'study_version': 1,
#       'total_count': 13006},
#      {'allele_count': 36717,
#       'common': False,
#       'local_row_id': 5940423,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'C',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': 'ExAC',
#       'study_version': 1,
#       'total_count': 119740},
#      {'allele_count': 9198,
#       'common': False,
#       'local_row_id': 128030033,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'C',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': 'GnomAD',
#       'study_version': 1,
#       'total_count': 29916},
#      {'allele_count': 8640,
#       'common': False,
#       'local_row_id': 93016551,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'C',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': 'TOPMED',
#       'study_version': 1,
#       'total_count': 29114},
#      {'allele_count': 1105,
#       'common': False,
#       'local_row_id': 44706681,
#       'observation': {'deleted_sequence': 'A',
#        'inserted_sequence': 'C',
#        'position': 39917514,
#        'seq_id': 'NC_000022.10'},
#       'study_name': 'TWINSUK',
#       'study_version': 1,
#       'total_count': 3708}],
#     'submissions': ['5336',
#      '85589',
#      '1542101',
#      '1543395',
#      '3172836',
#      '4399381',
#      '4428742',
#      '5298654',
#      '6052612',
#      '7998332',
#      '16261117',
#      '28504602',
#      '28505142',
#      '28506545',
#      '41518359',
#      '46563727',
#      '48402331',
#      '76868677',
#      '76897193',
#      '96126931',
#      '143466153',
#      '159744578',
#      '160724750',
#      '167982926',
#      '171998650',
#      '204095544',
#      '283644119',
#      '287573031',
#      '341187171',
#      '342543467',
#      '482104014',
#      '491193453',
#      '491572090',
#      '491825004',
#      '566657448',
#      '662586525',
#      '995377109',
#      '1067606697',
#      '1082676753',
#      '1367267142',
#      '1429264090',
#      '1584128112',
#      '1640046802',
#      '1683040835',
#      '1694358673',
#      '1699448412',
#      '1711570323',
#      '1938945194',
#      '1959982477',
#      '1969277163',
#      '2030245075',
#      '2136840570',
#      '2158864568',
#      '2414513736',
#      '2745159603',
#      '2750562012',
#      '2974676167',
#      '2985856796',
#      '3019346144',
#      '3022189307',
#      '3023073564']}],
#   'anchor': 'NC_000022.11:0039521509:1:snv',
#   'placements_with_allele': [{'alleles': [{'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'A',
#         'position': 39521509,
#         'seq_id': 'NC_000022.11'}},
#       'hgvs': 'NC_000022.11:g.39521510A='},
#      {'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'C',
#         'position': 39521509,
#         'seq_id': 'NC_000022.11'}},
#       'hgvs': 'NC_000022.11:g.39521510A>C'}],
#     'is_ptlp': True,
#     'placement_annot': {'is_aln_opposite_orientation': False,
#      'is_mismatch': False,
#      'mol_type': 'genomic',
#      'seq_id_traits_by_assembly': [{'assembly_accession': 'GCF_000001405.33',
#        'assembly_name': 'GRCh38.p7',
#        'is_alt': False,
#        'is_chromosome': True,
#        'is_patch': False,
#        'is_top_level': True}],
#      'seq_type': 'refseq_chromosome'},
#     'seq_id': 'NC_000022.11'},
#    {'alleles': [{'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'A',
#         'position': 39917514,
#         'seq_id': 'NC_000022.10'}},
#       'hgvs': 'NC_000022.10:g.39917515A='},
#      {'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'C',
#         'position': 39917514,
#         'seq_id': 'NC_000022.10'}},
#       'hgvs': 'NC_000022.10:g.39917515A>C'}],
#     'is_ptlp': False,
#     'placement_annot': {'is_aln_opposite_orientation': False,
#      'is_mismatch': False,
#      'mol_type': 'genomic',
#      'seq_id_traits_by_assembly': [{'assembly_accession': 'GCF_000001405.25',
#        'assembly_name': 'GRCh37.p13',
#        'is_alt': False,
#        'is_chromosome': True,
#        'is_patch': False,
#        'is_top_level': True}],
#      'seq_type': 'refseq_chromosome'},
#     'seq_id': 'NC_000022.10'},
#    {'alleles': [{'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'A',
#         'position': 951,
#         'seq_id': 'NM_001675.4'}},
#       'hgvs': 'NM_001675.4:c.65A='},
#      {'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'C',
#         'position': 951,
#         'seq_id': 'NM_001675.4'}},
#       'hgvs': 'NM_001675.4:c.65A>C'}],
#     'is_ptlp': False,
#     'placement_annot': {'is_aln_opposite_orientation': False,
#      'is_mismatch': False,
#      'mol_type': 'rna',
#      'seq_id_traits_by_assembly': [],
#      'seq_type': 'refseq_mrna'},
#     'seq_id': 'NM_001675.4'},
#    {'alleles': [{'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'A',
#         'position': 946,
#         'seq_id': 'NM_001675.2'}},
#       'hgvs': 'NM_001675.2:c.65A='},
#      {'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'C',
#         'position': 946,
#         'seq_id': 'NM_001675.2'}},
#       'hgvs': 'NM_001675.2:c.65A>C'}],
#     'is_ptlp': False,
#     'placement_annot': {'is_aln_opposite_orientation': False,
#      'is_mismatch': False,
#      'mol_type': 'rna',
#      'seq_id_traits_by_assembly': [],
#      'seq_type': 'refseq_mrna'},
#     'seq_id': 'NM_001675.2'},
#    {'alleles': [{'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'A',
#         'position': 344,
#         'seq_id': 'NM_182810.2'}},
#       'hgvs': 'NM_182810.2:c.65A='},
#      {'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'C',
#         'position': 344,
#         'seq_id': 'NM_182810.2'}},
#       'hgvs': 'NM_182810.2:c.65A>C'}],
#     'is_ptlp': False,
#     'placement_annot': {'is_aln_opposite_orientation': False,
#      'is_mismatch': False,
#      'mol_type': 'rna',
#      'seq_id_traits_by_assembly': [],
#      'seq_type': 'refseq_mrna'},
#     'seq_id': 'NM_182810.2'},
#    {'alleles': [{'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'A',
#         'position': 344,
#         'seq_id': 'NM_182810.1'}},
#       'hgvs': 'NM_182810.1:c.65A='},
#      {'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'C',
#         'position': 344,
#         'seq_id': 'NM_182810.1'}},
#       'hgvs': 'NM_182810.1:c.65A>C'}],
#     'is_ptlp': False,
#     'placement_annot': {'is_aln_opposite_orientation': False,
#      'is_mismatch': False,
#      'mol_type': 'rna',
#      'seq_id_traits_by_assembly': [],
#      'seq_type': 'refseq_mrna'},
#     'seq_id': 'NM_182810.1'},
#    {'alleles': [{'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'A',
#         'position': 823,
#         'seq_id': 'XM_017028807.1'}},
#       'hgvs': 'XM_017028807.1:c.65A='},
#      {'allele': {'spdi': {'deleted_sequence': 'A',
#         'inserted_sequence': 'C',
#         'position': 823,
#         'seq_id': 'XM_017028807.1'}},
#       'hgvs': 'XM_017028807.1:c.65A>C'}],
#     'is_ptlp': False,
#     'placement_annot': {'is_aln_opposite_orientation': False,
#      'is_mismatch': False,
#      'mol_type': 'rna',
#      'seq_id_traits_by_assembly': [],
#      'seq_type': 'refseq_mrna_pred'},
#     'seq_id': 'XM_017028807.1'},
#    {'alleles': [{'allele': {'spdi': {'deleted_sequence': 'Q',
#         'inserted_sequence': 'Q',
#         'position': 21,
#         'seq_id': 'NP_001666.2'}},
#       'hgvs': 'NP_001666.2:p.Gln22='},
#      {'allele': {'spdi': {'deleted_sequence': 'Q',
#         'inserted_sequence': 'P',
#         'position': 21,
#         'seq_id': 'NP_001666.2'}},
#       'hgvs': 'NP_001666.2:p.Gln22Pro'}],
#     'is_ptlp': False,
#     'placement_annot': {'is_aln_opposite_orientation': False,
#      'is_mismatch': False,
#      'mol_type': 'protein',
#      'seq_id_traits_by_assembly': [],
#      'seq_type': 'refseq_prot'},
#     'seq_id': 'NP_001666.2'},
#    {'alleles': [{'allele': {'spdi': {'deleted_sequence': 'Q',
#         'inserted_sequence': 'Q',
#         'position': 21,
#         'seq_id': 'NP_877962.1'}},
#       'hgvs': 'NP_877962.1:p.Gln22='},
#      {'allele': {'spdi': {'deleted_sequence': 'Q',
#         'inserted_sequence': 'P',
#         'position': 21,
#         'seq_id': 'NP_877962.1'}},
#       'hgvs': 'NP_877962.1:p.Gln22Pro'}],
#     'is_ptlp': False,
#     'placement_annot': {'is_aln_opposite_orientation': False,
#      'is_mismatch': False,
#      'mol_type': 'protein',
#      'seq_id_traits_by_assembly': [],
#      'seq_type': 'refseq_prot'},
#     'seq_id': 'NP_877962.1'},
#    {'alleles': [{'allele': {'spdi': {'deleted_sequence': 'Q',
#         'inserted_sequence': 'Q',
#         'position': 21,
#         'seq_id': 'XP_016884296.1'}},
#       'hgvs': 'XP_016884296.1:p.Gln22='},
#      {'allele': {'spdi': {'deleted_sequence': 'Q',
#         'inserted_sequence': 'P',
#         'position': 21,
#         'seq_id': 'XP_016884296.1'}},
#       'hgvs': 'XP_016884296.1:p.Gln22Pro'}],
#     'is_ptlp': False,
#     'placement_annot': {'is_aln_opposite_orientation': False,
#      'is_mismatch': False,
#      'mol_type': 'protein',
#      'seq_id_traits_by_assembly': [],
#      'seq_type': 'refseq_prot'},
#     'seq_id': 'XP_016884296.1'}],
#   'support': [{'create_date': '2000-09-19T17:02Z',
#     'id': {'type': 'subsnp', 'value': 'ss5336'},
#     'revision_added': '52',
#     'submitter_handle': 'DEBNICK'},
#    {'create_date': '2002-10-8T20:21Z',
#     'id': {'type': 'subsnp', 'value': 'ss85589'},
#     'revision_added': '111',
#     'submitter_handle': 'TSC-CSHL'},
#    {'create_date': '2000-10-4T23:48Z',
#     'id': {'type': 'subsnp', 'value': 'ss1542101'},
#     'revision_added': '86',
#     'submitter_handle': 'LEE'},
#    {'create_date': '2000-10-4T23:48Z',
#     'id': {'type': 'subsnp', 'value': 'ss1543395'},
#     'revision_added': '86',
#     'submitter_handle': 'LEE'},
#    {'create_date': '2001-08-15T12:13Z',
#     'id': {'type': 'subsnp', 'value': 'ss3172836'},
#     'revision_added': '98',
#     'submitter_handle': 'WIAF-CSNP'},
#    {'create_date': '2002-05-29T11:17Z',
#     'id': {'type': 'subsnp', 'value': 'ss4399381'},
#     'revision_added': '106',
#     'submitter_handle': 'LEE'},
#    {'create_date': '2002-05-29T11:17Z',
#     'id': {'type': 'subsnp', 'value': 'ss4428742'},
#     'revision_added': '106',
#     'submitter_handle': 'LEE'},
#    {'create_date': '2002-10-8T20:21Z',
#     'id': {'type': 'subsnp', 'value': 'ss5298654'},
#     'revision_added': '111',
#     'submitter_handle': 'TSC-CSHL'},
#    {'create_date': '2003-02-20T13:04Z',
#     'id': {'type': 'subsnp', 'value': 'ss6052612'},
#     'revision_added': '111',
#     'submitter_handle': 'SC_JCM'},
#    {'create_date': '2003-04-21T10:22Z',
#     'id': {'type': 'subsnp', 'value': 'ss7998332'},
#     'revision_added': '114',
#     'submitter_handle': 'SC_SNP'},
#    {'create_date': '2004-02-28T21:15Z',
#     'id': {'type': 'subsnp', 'value': 'ss16261117'},
#     'revision_added': '124',
#     'submitter_handle': 'CGAP-GAI'},
#    {'create_date': '2004-09-24T16:54Z',
#     'id': {'type': 'subsnp', 'value': 'ss28504602'},
#     'revision_added': '126',
#     'submitter_handle': 'MGC_GENOME_DIFF'},
#    {'create_date': '2004-09-24T16:54Z',
#     'id': {'type': 'subsnp', 'value': 'ss28505142'},
#     'revision_added': '126',
#     'submitter_handle': 'MGC_GENOME_DIFF'},
#    {'create_date': '2004-09-24T16:54Z',
#     'id': {'type': 'subsnp', 'value': 'ss28506545'},
#     'revision_added': '126',
#     'submitter_handle': 'MGC_GENOME_DIFF'},
#    {'create_date': '2006-03-11T06:54Z',
#     'id': {'type': 'subsnp', 'value': 'ss41518359'},
#     'revision_added': '126',
#     'submitter_handle': 'ABI'},
#    {'create_date': '2006-03-11T06:54Z',
#     'id': {'type': 'subsnp', 'value': 'ss46563727'},
#     'revision_added': '126',
#     'submitter_handle': 'IMCJ-GDT'},
#    {'create_date': '2006-03-11T06:54Z',
#     'id': {'type': 'subsnp', 'value': 'ss48402331'},
#     'revision_added': '126',
#     'submitter_handle': 'APPLERA_GI'},
#    {'create_date': '2007-12-7T20:32Z',
#     'id': {'type': 'subsnp', 'value': 'ss76868677'},
#     'revision_added': '129',
#     'submitter_handle': 'CGM_KYOTO'},
#    {'create_date': '2007-12-7T20:32Z',
#     'id': {'type': 'subsnp', 'value': 'ss76897193'},
#     'revision_added': '129',
#     'submitter_handle': 'SI_EXO'},
#    {'create_date': '2009-02-7T03:28Z',
#     'id': {'type': 'subsnp', 'value': 'ss96126931'},
#     'revision_added': '130',
#     'submitter_handle': 'HUMANGENOME_JCVI'},
#    {'create_date': '2009-12-1T15:44Z',
#     'id': {'type': 'subsnp', 'value': 'ss143466153'},
#     'revision_added': '131',
#     'submitter_handle': 'ENSEMBL'},
#    {'create_date': '2009-12-1T15:44Z',
#     'id': {'type': 'subsnp', 'value': 'ss159744578'},
#     'revision_added': '131',
#     'submitter_handle': 'SEATTLESEQ'},
#    {'create_date': '2009-12-1T15:44Z',
#     'id': {'type': 'subsnp', 'value': 'ss160724750'},
#     'revision_added': '131',
#     'submitter_handle': 'ILLUMINA'},
#    {'create_date': '2010-07-4T16:01Z',
#     'id': {'type': 'subsnp', 'value': 'ss167982926'},
#     'revision_added': '132',
#     'submitter_handle': 'COMPLETE_GENOMICS'},
#    {'create_date': '2010-07-4T16:01Z',
#     'id': {'type': 'subsnp', 'value': 'ss171998650'},
#     'revision_added': '132',
#     'submitter_handle': 'COMPLETE_GENOMICS'},
#    {'create_date': '2010-07-4T16:01Z',
#     'id': {'type': 'subsnp', 'value': 'ss204095544'},
#     'revision_added': '132',
#     'submitter_handle': 'BUSHMAN'},
#    {'create_date': '2012-05-4T12:43Z',
#     'id': {'type': 'subsnp', 'value': 'ss283644119'},
#     'revision_added': '137',
#     'submitter_handle': 'GMI'},
#    {'create_date': '2013-04-25T23:59Z',
#     'id': {'type': 'subsnp', 'value': 'ss287573031'},
#     'revision_added': '138',
#     'submitter_handle': 'GMI'},
#    {'create_date': '2011-05-9T22:13Z',
#     'id': {'type': 'subsnp', 'value': 'ss341187171'},
#     'revision_added': '134',
#     'submitter_handle': '1000GENOMES'},
#    {'create_date': '2011-05-9T22:13Z',
#     'id': {'type': 'subsnp', 'value': 'ss342543467'},
#     'revision_added': '134',
#     'submitter_handle': 'NHLBI-ESP'},
#    {'create_date': '2015-09-8T16:25Z',
#     'id': {'type': 'subsnp', 'value': 'ss482104014'},
#     'revision_added': '146',
#     'submitter_handle': 'ILLUMINA'},
#    {'create_date': '2012-05-4T12:43Z',
#     'id': {'type': 'subsnp', 'value': 'ss491193453'},
#     'revision_added': '137',
#     'submitter_handle': '1000GENOMES'},
#    {'create_date': '2012-05-4T12:43Z',
#     'id': {'type': 'subsnp', 'value': 'ss491572090'},
#     'revision_added': '137',
#     'submitter_handle': 'EXOME_CHIP'},
#    {'create_date': '2012-05-4T12:43Z',
#     'id': {'type': 'subsnp', 'value': 'ss491825004'},
#     'revision_added': '137',
#     'submitter_handle': 'CLINSEQ_SNP'},
#    {'create_date': '2013-04-25T23:59Z',
#     'id': {'type': 'subsnp', 'value': 'ss566657448'},
#     'revision_added': '138',
#     'submitter_handle': 'TISHKOFF'},
#    {'create_date': '2013-04-25T23:59Z',
#     'id': {'type': 'subsnp', 'value': 'ss662586525'},
#     'revision_added': '138',
#     'submitter_handle': 'SSMP'},
#    {'create_date': '2014-08-21T15:37Z',
#     'id': {'type': 'subsnp', 'value': 'ss995377109'},
#     'revision_added': '142',
#     'submitter_handle': 'EVA-GONL'},
#    {'create_date': '2014-08-21T15:37Z',
#     'id': {'type': 'subsnp', 'value': 'ss1067606697'},
#     'revision_added': '142',
#     'submitter_handle': 'JMKIDD_LAB'},
#    {'create_date': '2014-08-21T15:37Z',
#     'id': {'type': 'subsnp', 'value': 'ss1082676753'},
#     'revision_added': '142',
#     'submitter_handle': 'JMKIDD_LAB'},
#    {'create_date': '2014-08-21T15:37Z',
#     'id': {'type': 'subsnp', 'value': 'ss1367267142'},
#     'revision_added': '142',
#     'submitter_handle': '1000GENOMES'},
#    {'create_date': '2015-04-1T10:43Z',
#     'id': {'type': 'subsnp', 'value': 'ss1429264090'},
#     'revision_added': '144',
#     'submitter_handle': 'DDI'},
#    {'create_date': '2015-04-1T10:43Z',
#     'id': {'type': 'subsnp', 'value': 'ss1584128112'},
#     'revision_added': '144',
#     'submitter_handle': 'EVA_FINRISK'},
#    {'create_date': '2015-04-1T10:43Z',
#     'id': {'type': 'subsnp', 'value': 'ss1640046802'},
#     'revision_added': '144',
#     'submitter_handle': 'EVA_UK10K_ALSPAC'},
#    {'create_date': '2015-04-1T10:43Z',
#     'id': {'type': 'subsnp', 'value': 'ss1683040835'},
#     'revision_added': '144',
#     'submitter_handle': 'EVA_UK10K_TWINSUK'},
#    {'create_date': '2015-04-1T10:43Z',
#     'id': {'type': 'subsnp', 'value': 'ss1694358673'},
#     'revision_added': '144',
#     'submitter_handle': 'EVA_EXAC'},
#    {'create_date': '2015-04-1T10:43Z',
#     'id': {'type': 'subsnp', 'value': 'ss1699448412'},
#     'revision_added': '144',
#     'submitter_handle': 'EVA_DECODE'},
#    {'create_date': '2015-04-1T10:43Z',
#     'id': {'type': 'subsnp', 'value': 'ss1711570323'},
#     'revision_added': '144',
#     'submitter_handle': 'EVA_MGP'},
#    {'create_date': '2016-02-12T12:05Z',
#     'id': {'type': 'subsnp', 'value': 'ss1938945194'},
#     'revision_added': '147',
#     'submitter_handle': 'WEILL_CORNELL_DGM'},
#    {'create_date': '2016-02-12T12:05Z',
#     'id': {'type': 'subsnp', 'value': 'ss1959982477'},
#     'revision_added': '147',
#     'submitter_handle': 'ILLUMINA'},
#    {'create_date': '2016-07-19T13:00Z',
#     'id': {'type': 'subsnp', 'value': 'ss1969277163'},
#     'revision_added': '147',
#     'submitter_handle': 'GENOMED'},
#    {'create_date': '2016-09-14T10:20Z',
#     'id': {'type': 'subsnp', 'value': 'ss2030245075'},
#     'revision_added': '149',
#     'submitter_handle': 'JJLAB'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'subsnp', 'value': 'ss2136840570'},
#     'revision_added': '150',
#     'submitter_handle': 'CSHL'},
#    {'create_date': '2016-12-20T12:49Z',
#     'id': {'type': 'subsnp', 'value': 'ss2158864568'},
#     'revision_added': '150',
#     'submitter_handle': 'USC_VALOUEV'},
#    {'create_date': '2016-12-20T12:49Z',
#     'id': {'type': 'subsnp', 'value': 'ss2414513736'},
#     'revision_added': '150',
#     'submitter_handle': 'TOPMED'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'subsnp', 'value': 'ss2745159603'},
#     'revision_added': '150',
#     'submitter_handle': 'GNOMAD'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'subsnp', 'value': 'ss2750562012'},
#     'revision_added': '150',
#     'submitter_handle': 'GNOMAD'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'subsnp', 'value': 'ss2974676167'},
#     'revision_added': '150',
#     'submitter_handle': 'GNOMAD'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'subsnp', 'value': 'ss2985856796'},
#     'revision_added': '150',
#     'submitter_handle': 'AFFY'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'subsnp', 'value': 'ss3019346144'},
#     'revision_added': '150',
#     'submitter_handle': 'SWEGEN'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'subsnp', 'value': 'ss3022189307'},
#     'revision_added': '150',
#     'submitter_handle': 'ILLUMINA'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'subsnp', 'value': 'ss3023073564'},
#     'revision_added': '150',
#     'submitter_handle': 'EVA_SAMSUNG_MC'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'frequency', 'value': '1000Genomes.1:80822908'},
#     'revision_added': '150',
#     'submitter_handle': '1000Genomes'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'frequency', 'value': 'ALSPAC.1:44706681'},
#     'revision_added': '150',
#     'submitter_handle': 'ALSPAC'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'frequency', 'value': 'ESP6500SI-V2.1:1907169'},
#     'revision_added': '150',
#     'submitter_handle': 'ESP6500SI-V2'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'frequency', 'value': 'ExAC.1:5940423'},
#     'revision_added': '150',
#     'submitter_handle': 'ExAC'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'frequency', 'value': 'GnomAD.1:128030033'},
#     'revision_added': '150',
#     'submitter_handle': 'GnomAD'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'frequency', 'value': 'TOPMED.1:93016551'},
#     'revision_added': '150',
#     'submitter_handle': 'TOPMED'},
#    {'create_date': '2018-03-4T14:03Z',
#     'id': {'type': 'frequency', 'value': 'TWINSUK.1:44706681'},
#     'revision_added': '150',
#     'submitter_handle': 'TWINSUK'}],
#   'variant_type': 'snv'},
#  'refsnp_id': '4894'}
