# %% [markdown]
# # ABI Trace files
#
# Developed by Bow. Code and documentation at: https://github.com/bow/abifpy
#
# Modified by me (slightly)

# %%
import biu

# %%
abi = biu.formats.ABI('example_files/example.ab1')

# %%
abi.chromatogram(xlim=(30,40))

# %%
abi.chromatogram(xlim=(30,60), highlight=(30,40))
