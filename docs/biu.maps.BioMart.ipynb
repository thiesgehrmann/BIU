# %%
import biu

# %%
bm = biu.maps.BioMart()

# %%
bm

# %%
print(bm)
# Out:
# BioMart object
#  Objects:
#   * [ ] ensembl_gene_id
#   * [ ] ensembl_transcript_id
#   * [ ] ensembl_peptide_id
#   * [ ] entrezgene
#   * [ ] ucsc
#  Files:
#   * [X] db : grch37_gene_trans_prot_geneid_hgnc/data.tsv

# %%
#bm.ensembl_peptide_id.lookup('ENSP00000456546', singleton=True).ensembl_transcript_id

# %%
bm2 = biu.maps.BioMart(version=None,
                       database='dmelanogaster_gene_ensembl', 
                       attributes=['ensembl_gene_id','ensembl_transcript_id', 'ensembl_peptide_id'])

# %%
print(bm2)
# Out:
# BioMart object
#  Objects:
#   * [ ] ensembl_gene_id
#   * [ ] ensembl_transcript_id
#   * [ ] ensembl_peptide_id
#  Files:
#   * [ ] db : www.ensembl.org.dmelanogaster_gene_ensembl.ensembl_gene_id_ensembl_transcript_id_ensembl_peptide_id/data.tsv

# %%
bm.ensembl_gene_id.table
# Out:
#         ensembl_gene_id ensembl_transcript_id ensembl_peptide_id entrezgene  \
# 0       ENSG00000261657       ENST00000566782    ENSP00000456546     115286
# 1       ENSG00000261657       ENST00000562780    ENSP00000457004     115286
# 2       ENSG00000261657       ENST00000569579    ENSP00000456312     115286
# 3       ENSG00000261657       ENST00000568242    ENSP00000456306     115286
# 4       ENSG00000261657       ENST00000565530                        115286
# 5       ENSG00000223116       ENST00000411184
# 6       ENSG00000233440       ENST00000418454
# 7       ENSG00000207157       ENST00000384428
# 8       ENSG00000229483       ENST00000414345
# 9       ENSG00000252952       ENST00000517143                     100873766
# 10      ENSG00000235205       ENST00000452855
# 11      ENSG00000232849       ENST00000443228
# 12      ENSG00000236803       ENST00000418445
# 13      ENSG00000252365       ENST00000516556
# 14      ENSG00000232163       ENST00000434567
# ...

# %%
 [ p for p in 'http://www.ensembl.org/biomart/martservice?query'.split('/') if '.org' in p ][0]
# Out:
# 'www.ensembl.org'
