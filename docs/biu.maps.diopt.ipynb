# %% [markdown]
# # Access DIOPT mappings
#
# DIOPT is an integrative orthology database, which uses integrates the output of 18 tools to make orthology predictions between a set of species. We make use of the www.gene2function.org service, which allows us to retrieve results more easily.

# %%
import biu
import pandas as pd

# %% [markdown]
# ## Inspecting the DIOPT object

# %%
diopt = biu.maps.DIOPT()
print(diopt)
# Out:
# DIOPT object
#  Objects:
#  Files:
#   * [X] data : /home/tgehrmann/repos/BIU/docs/diopt/h_sapiens.data.sqlite

# %% [markdown]
# ## Querying the DIOPT object
# The DIOPT object takes as input a single NCBI Entrez Gene ID. This can be either a string or a number.
# It returns one record for each orthologous gene found.

# %%
diopt[4763]
# Out:
# [DIOPTResult(species='h_sapiens', ncbi='4763', symbol='NF1', id='7765', score='NA', confidence='', database='HGNC'),
#  DIOPTResult(species='m_musculus', ncbi='18015', symbol='Nf1', id='97306', score='15/16', confidence='high', database='MGI'),
#  DIOPTResult(species='r_norvegicus', ncbi='24592', symbol='Nf1', id='3168', score='11/14', confidence='high', database='RGD'),
#  DIOPTResult(species='x_tropicalis', ncbi='100493879', symbol='nf1', id='XB-GENE-488024', score='6/12', confidence='high', database='Xenbase'),
#  DIOPTResult(species='d_reiro', ncbi='564518', symbol='nf1b', id='ZDB-GENE-091111-4', score='13/15', confidence='high', database='ZFIN'),
#  DIOPTResult(species='d_melanogaster', ncbi='43149', symbol='Nf1', id='FBgn0015269', score='12/15', confidence='high', database='FLYBASE'),
#  DIOPTResult(species='c_elegans', ncbi='180530', symbol='gap-1', id='WBGene00001515', score='1/15', confidence='low', database='WormBase'),
#  DIOPTResult(species='s_cerevisiae', ncbi='852437', symbol='IRA1', id='S000000344', score='9/15', confidence='high', database='SGD'),
#  DIOPTResult(species='s_pombe', ncbi='2540440', symbol='gap1', id='SPBC646.12c', score='1/12', confidence='low', database='PomBase')]

# %% [markdown]
# # Bulk lookup of orthologs
#
# Sometimes it is handy to lookup the orthologs of multiple genes at a time. This can be done with the batch function:

# %%
#Let's first get some entrez Gene IDs:
symbols = ['NF1', 'RRAS', 'DUSP3', 'ATF4', 'RAF1', 'MKNK2', 'SHC4', 'IRS1',
       'LAMTOR3', 'SHC2', 'RASGRF2', 'RASGRP3', 'ETS2', 'ETS1', 'EGFR',
       'RPS6KA4', 'PTPRR', 'RASA1']

bm = biu.maps.BioMart()

ncbiFromSymbol = lambda s: list(set([ r.entrezgene for r in bm.hgnc_symbol[s] ]))[0]
geneIDs = [ ncbiFromSymbol(s) for s in symbols ]

# %%
diopt.batch(geneIDs).rename(index=dict(zip(geneIDs,symbols)))
# Out:
#                 h_sapiens               s_pombe         s_cerevisiae  \
# NF1           (NF1, 7765)                    ()   (IRA1, S000000344)
# RRAS        (RRAS, 10447)  (ras1, SPAC17H9.09c)   (RAS1, S000005627)
# DUSP3       (DUSP3, 3069)   (pmp1, SPBC1685.01)   (YVH1, S000001465)
# ATF4          (ATF4, 786)                    ()                   ()
# RAF1         (RAF1, 9829)                    ()                   ()
# MKNK2       (MKNK2, 7111)                    ()                   ()
# SHC4        (SHC4, 16743)                    ()                   ()
# IRS1         (IRS1, 6125)                    ()                   ()
# LAMTOR3  (LAMTOR3, 15606)                    ()                   ()
# SHC2        (SHC2, 29869)                    ()                   ()
# RASGRF2   (RASGRF2, 9876)   (ste6, SPCC1442.01)  (CDC25, S000004301)
# RASGRP3  (RASGRP3, 14545)                    ()                   ()
# ETS2         (ETS2, 3489)                    ()                   ()
# ETS1         (ETS1, 3488)                    ()                   ()
# EGFR         (EGFR, 3236)                    ()                   ()
# RPS6KA4  (RPS6KA4, 10433)    (psk1, SPCC4G3.08)   (YPK3, S000000232)
# PTPRR       (PTPRR, 9680)                    ()   (PTP1, S000002389)
# RASA1       (RASA1, 9871)                    ()   (BUD2, S000001575)
#
#                          c_elegans         d_melanogaster  \
# NF1                             ()     (Nf1, FBgn0015269)
# RRAS       (ras-1, WBGene00004310)  (Ras64B, FBgn0003206)
# DUSP3    (C16A3.2, WBGene00015807)  (CG7378, FBgn0030976)
# ATF4       (atf-5, WBGene00000221)     (crc, FBgn0000370)
# RAF1      (lin-45, WBGene00003030)     (Raf, FBgn0003079)
# MKNK2      (mnk-1, WBGene00011304)     (Lk6, FBgn0017581)
# SHC4       (shc-1, WBGene00018788)     (Shc, FBgn0015296)
# IRS1                            ()   (chico, FBgn0024248)
# LAMTOR3   (lmtr-3, WBGene00007390)  (CG5110, FBgn0032642)
# SHC2       (shc-1, WBGene00018788)     (Shc, FBgn0015296)
# RASGRF2                         ()                     ()
# RASGRP3   (rgef-1, WBGene00009100)                     ()
# ETS2       (ets-9, WBGene00016865)     (pnt, FBgn0003118)
# ETS1       (ets-9, WBGene00016865)     (pnt, FBgn0003118)
# EGFR      (let-23, WBGene00002299)    (Egfr, FBgn0003731)
# RPS6KA4   (rskn-2, WBGene00008311)   (JIL-1, FBgn0020412)
# PTPRR    (T27A3.5, WBGene00020841)  (PTP-ER, FBgn0016641)
# RASA1      (gap-3, WBGene00021238)     (vap, FBgn0003969)
#
#                                 d_reiro                    x_tropicalis  \
# NF1           (nf1b, ZDB-GENE-091111-4)           (nf1, XB-GENE-488024)
# RRAS        (rras, ZDB-GENE-041010-217)          (rras, XB-GENE-493188)
# DUSP3       (dusp3a, ZDB-GENE-111207-3)         (dusp3, XB-GENE-961523)
# ATF4      (atf4a, ZDB-GENE-040426-2340)          (atf4, XB-GENE-983841)
# RAF1         (raf1b, ZDB-GENE-090826-2)         (raf1, XB-GENE-6053330)
# MKNK2       (mknk2b, ZDB-GENE-030829-2)         (mknk2, XB-GENE-491527)
# SHC4        (shc2, ZDB-GENE-050208-666)          (shc4, XB-GENE-490134)
# IRS1        (irs1, ZDB-GENE-030131-872)          (irs1, XB-GENE-478672)
# LAMTOR3  (lamtor3, ZDB-GENE-050522-345)  (lamtor3-like, XB-GENE-942321)
# SHC2        (shc2, ZDB-GENE-050208-666)         (shc2, XB-GENE-6073771)
# RASGRF2   (rasgrf2b, ZDB-GENE-060504-1)       (rasgrf2, XB-GENE-483993)
# RASGRP3   (rasgrp3, ZDB-GENE-070424-82)       (rasgrp3, XB-GENE-492465)
# ETS2        (ets2, ZDB-GENE-050522-552)         (ets2, XB-GENE-6084129)
# ETS1          (ets1, ZDB-GENE-021115-5)         (ets1, XB-GENE-6465484)
# EGFR         (egfra, ZDB-GENE-030918-1)         (egfr, XB-GENE-6067152)
# RPS6KA4  (rps6ka4, ZDB-GENE-060526-284)      (rps6ka4, XB-GENE-5759516)
# PTPRR        (ptprr, ZDB-GENE-101029-2)         (ptprr, XB-GENE-961693)
# RASA1    (rasa1a, ZDB-GENE-030131-4694)        (rasa1, XB-GENE-6085075)
#
#                  m_musculus        r_norvegicus
# NF1            (Nf1, 97306)         (Nf1, 3168)
# RRAS          (Rras, 98179)     (Rras, 1311443)
# DUSP3      (Dusp3, 1919599)    (Dusp3, 1560049)
# ATF4          (Atf4, 88096)      (Atf4, 621863)
# RAF1          (Raf1, 97847)        (Raf1, 3531)
# MKNK2       (Mknk2, 894279)    (Mknk2, 1305728)
# SHC4        (Shc4, 2655364)     (Shc4, 1583644)
# IRS1          (Irs1, 99454)        (Irs1, 2922)
# LAMTOR3  (Lamtor3, 1929467)  (Lamtor3, 1307133)
# SHC2         (Shc2, 106180)     (Shc2, 1307137)
# RASGRF2   (Rasgrf2, 109137)    (Rasgrf2, 69413)
# RASGRP3  (Rasgrp3, 3028579)  (Rasgrp3, 1304612)
# ETS2          (Ets2, 95456)     (Ets2, 1584977)
# ETS1          (Ets1, 95455)        (Ets1, 2583)
# EGFR          (Egfr, 95294)        (Egfr, 2543)
# RPS6KA4  (Rps6ka4, 1930076)  (Rps6ka4, 1307277)
# PTPRR       (Ptprr, 109559)     (Ptprr, 620780)
# RASA1        (Rasa1, 97860)       (Rasa1, 3537)
