# %% [markdown]
# # Access Gene Ontology

# %%
import biu
# Out:
# W: The following dependencies of BIU are missing. Functionality of BIU will be affected.
# W:   tabix, intervaltree, vcf
# W: Some optional dependencies of BIU are missing. Functionality of BIU may be affected.
# W:   xlrd, matplotlib_venn, fastcluster, openpyxl

# %%
go = biu.db.GO()

# %%
print(go)
# Out:
# GO object
#  Version: human
#  Objects:
#   * [ ] terminfo
#  Files:
#   * [ ] gaf : /home/tgehrmann/repos/BIU/docs/biu/data/geneOntology/human/annots.gaf
#   * [ ] terminfo : /home/tgehrmann/repos/BIU/docs/biu/data/geneOntology/human/terminfo.tsv

# %%
go.objects
# Out:
# D: curl -L  'http://geneontology.org/gene-associations/goa_human.gaf.gz' > '/home/tgehrmann/repos/BIU/docs/biu/downloads/67def37e1c6b755c0cbfb09da6b74203e9192838'
# 0
# D: gunzip < '/home/tgehrmann/repos/BIU/docs/biu/downloads/67def37e1c6b755c0cbfb09da6b74203e9192838' > '/home/tgehrmann/repos/BIU/docs/biu/downloads/67def37e1c6b755c0cbfb09da6b74203e9192838.gunzipped'
# 0
# D: cp '/home/tgehrmann/repos/BIU/docs/biu/downloads/67def37e1c6b755c0cbfb09da6b74203e9192838.gunzipped' '/home/tgehrmann/repos/BIU/biu/data/geneOntology/human/annots.gaf'
# 0
# /home/tgehrmann/repos/BIU/docs/biu/structures/dataset.py:117: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   return self._getObject(oname)
# [nan,
#  'A0A024R161',
#  'A0A024RBG1',
#  'A0A075B6H9',
#  'A0A075B6I0',
#  'A0A075B6I1',
#  'A0A075B6I4',
#  'A0A075B6I9',
#  'A0A075B6J1',
#  'A0A075B6J6',
#  'A0A075B6J9',
#  'A0A075B6K0',
#  'A0A075B6K2',
#  'A0A075B6K4',
#  'A0A075B6K5',
# ...

# %%
go.terminfo.id['GO:0002181'][0].name
# Out:
# 'cytoplasmic translation'
